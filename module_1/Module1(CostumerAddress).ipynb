# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
data = pd.read_excel("CostumerAddress.xlsx")
data.head(5)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
data.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
data["state"] = data["state"].replace("New South Wales", "NSW")
data["state"] = data["state"].replace("Victoria", "VIC")
data.head(10)
# Out:
#    customer_id                  address  postcode state    country  \
# 0            1       060 Morning Avenue      2016   NSW  Australia
# 1            2      6 Meadow Vale Court      2153   NSW  Australia
# 2            4       0 Holy Cross Court      4211   QLD  Australia
# 3            5      17979 Del Mar Point      2448   NSW  Australia
# 4            6         9 Oakridge Court      3216   VIC  Australia
# 5            7         4 Delaware Trail      2210   NSW  Australia
# 6            8      49 Londonderry Lane      2650   NSW  Australia
# 7            9          97736 7th Trail      2023   NSW  Australia
# 8           11     93405 Ludington Park      3044   VIC  Australia
# 9           12  44339 Golden Leaf Alley      4557   QLD  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9
# 5                   9
# 6                   4
# 7                  12
# ...

# %%
data.to_csv("Cleaned_CoatumerAddress.csv", index = False)
